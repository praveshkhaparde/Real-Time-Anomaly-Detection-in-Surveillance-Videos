# %% [markdown]
# # Roboflow's Object Tracking Tutorial
#
# Track your objects today, with the object detection model you have already trained - no additional featurizing models required!!
#
# Detection Engines Currently Supported:
# * Roboflow Inference API
# * yolov5
# * yolov4 (coming soon)
#
# We recommend having the companion [object tracking how to blog post](https://blog.roboflow.com/object-tracking-how-to/) up in another tab.

# %%
# !pip install torch torchvision torchaudio
# Out:
# Collecting torch
#   Using cached torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading torchvision-0.22.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/dist-packages (from torch) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/dist-packages (from torch) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/dist-packages (from torch) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.1->torch) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Using cached torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
# Downloading torchvision-0.22.1-cp311-cp311-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 16.5 MB/s eta 0:00:00
# Downloading torchaudio-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 111.2 MB/s eta 0:00:00
# Installing collected packages: torch, torchvision, torchaudio
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [torchaudio]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.7.1 which is incompatible.
# Successfully installed torch-2.7.1 torchaudio-2.7.1 torchvision-0.22.1

# %%
# !git clone https://github.com/roboflow-ai/zero-shot-object-tracking
# Out:
# Cloning into 'zero-shot-object-tracking'...
# remote: Enumerating objects: 522, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 522 (delta 1), reused 9 (delta 1), pack-reused 513 (from 1)
# Receiving objects: 100% (522/522), 88.05 MiB | 40.52 MiB/s, done.
# Resolving deltas: 100% (227/227), done.

# %%
# !nvidia-smi
# Out:
# Wed Jul 16 19:06:23 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %cd zero-shot-object-tracking
# Out:
# /content/zero-shot-object-tracking

# %%
pwd
# Out:
# '/content/zero-shot-object-tracking'

# %%
# !ls data/video
# Out:
# cars.mp4  fish.mp4  test.mp4

# %%
# # You need to follow the authentication link to view the video
# !pip install -U kora
# from kora.drive import upload_public
# url = upload_public('data/video/cars.mp4')
# # then display it
# from IPython.display import HTML
# HTML(f"""<video src={url} width=500 controls/>""")

# %%
# !pip install --upgrade pip
# !pip install -r requirements.txt
# !pip install ftfy
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 28.7 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.7.1 which is incompatible.
# Successfully installed pip-25.1.1
# Requirement already satisfied: Cython in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (3.0.12)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (4.11.0.86)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (11.2.1)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (6.0.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (1.15.3)
# Requirement already satisfied: tensorboard>=2.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (2.18.0)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (2.7.1)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (4.67.1)
# Collecting requests==2.26.0 (from -r requirements.txt (line 15))
#   Downloading requests-2.26.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting PyYAML>=5.3 (from -r requirements.txt (line 9))
#   Downloading PyYAML-5.4.1.tar.gz (175 kB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1

# %%
# !git clone https://github.com/openai/CLIP.git CLIP-repo
# !cp -r ./CLIP-repo/clip ./clip
# Out:
# Cloning into 'CLIP-repo'...
# remote: Enumerating objects: 256, done.
# remote: Total 256 (delta 0), reused 0 (delta 0), pack-reused 256 (from 1)
# Receiving objects: 100% (256/256), 8.93 MiB | 24.44 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %%
#run zeroshot object tracking, point to your video and your detection engine
# !python clip_object_tracker.py --source /content/zero-shot-object-tracking/data/video/fish.mp4 --detection-engine yolov5

#Roboflow Inference API
#!python clip_object_tracker.py --source data/video/cards.mp4 --url https://detect.roboflow.com/playing-cards-ow27d/1 --api_key ROBOFLOW_API_KEY --info
# Out:
# Namespace(weights='yolov5s.pt', cfg='yolov4.cfg', names='coco.names', source='/content/zero-shot-object-tracking/data/video/fish.mp4', img_size=640, confidence=0.4, overlap=0.3, thickness=3, device='', view_img=False, save_txt=False, save_conf=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, nms_max_overlap=1.0, max_cosine_distance=0.4, nn_budget=None, api_key=None, url=None, info=False, detection_engine='yolov5')
# Fusing layers...
# Using torch 2.7.1+cu126 CUDA:0 (Tesla T4, 15095.0625MB)
#
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4314.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# video 1/1 (1/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.095s)
# video 1/1 (2/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 forks,
# [Tracks] 1
# Done. (0.112s)
# video 1/1 (3/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (4/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 forks,
# [Tracks] 1
# Done. (0.010s)
# video 1/1 (5/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 forks,
# [Tracks] 1
# Done. (0.010s)
# video 1/1 (6/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.012s)
# video 1/1 (7/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (8/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (9/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (10/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (11/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (12/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (13/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (14/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (15/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.015s)
# video 1/1 (16/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (17/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (18/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (19/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (20/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (21/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (22/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (23/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (24/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (25/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (26/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (27/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (28/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (29/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (30/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.012s)
# video 1/1 (31/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.011s)
# video 1/1 (32/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.011s)
# video 1/1 (33/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.011s)
# video 1/1 (34/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (35/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (36/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.013s)
# video 1/1 (37/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.012s)
# video 1/1 (38/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (39/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (40/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (41/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (42/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (43/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (44/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (45/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (46/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (47/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (48/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (49/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 2
# Done. (0.012s)
# video 1/1 (50/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (51/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (52/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (53/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (54/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (55/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.015s)
# video 1/1 (56/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.012s)
# video 1/1 (57/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (58/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (59/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (60/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (61/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (62/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (63/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (64/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.011s)
# video 1/1 (65/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.011s)
# video 1/1 (66/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (67/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.010s)
# video 1/1 (68/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (69/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (70/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (71/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (72/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 2
# Done. (0.011s)
# video 1/1 (73/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (74/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (75/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (76/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (77/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (78/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (79/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (80/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (81/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (82/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (83/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (84/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (85/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (86/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (87/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (88/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (89/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (90/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (91/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (92/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (93/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (94/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (95/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (96/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (97/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (98/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (99/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (100/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.014s)
# video 1/1 (101/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (102/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (103/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (104/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (105/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (106/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (107/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (108/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (109/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (110/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (111/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 2
# Done. (0.013s)
# video 1/1 (112/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 2
# Done. (0.013s)
# video 1/1 (113/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.014s)
# video 1/1 (114/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.016s)
# video 1/1 (115/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 kites,
# [Tracks] 2
# Done. (0.013s)
# video 1/1 (116/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.013s)
# video 1/1 (117/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (118/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 2
# Done. (0.015s)
# video 1/1 (119/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 2
# Done. (0.013s)
# video 1/1 (120/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 2
# Done. (0.014s)
# video 1/1 (121/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 2
# Done. (0.012s)
# video 1/1 (122/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds, 1 kites,
# [Tracks] 3
# Done. (0.013s)
# video 1/1 (123/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.031s)
# video 1/1 (124/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.012s)
# video 1/1 (125/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.012s)
# video 1/1 (126/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 3
# Done. (0.013s)
# video 1/1 (127/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 frisbees,
# [Tracks] 3
# Done. (0.016s)
# video 1/1 (128/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 3
# Done. (0.015s)
# video 1/1 (129/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 bears, 1 kites,
# [Tracks] 4
# Done. (0.013s)
# video 1/1 (130/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 bears,
# [Tracks] 4
# Done. (0.028s)
# video 1/1 (131/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 kites,
# [Tracks] 4
# Done. (0.012s)
# video 1/1 (132/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.012s)
# video 1/1 (133/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (134/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.015s)
# video 1/1 (135/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (136/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 4
# Done. (0.012s)
# video 1/1 (137/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.013s)
# video 1/1 (138/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.013s)
# video 1/1 (139/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (140/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (141/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (142/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (143/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (144/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (145/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.015s)
# video 1/1 (146/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.018s)
# video 1/1 (147/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.015s)
# video 1/1 (148/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.012s)
# video 1/1 (149/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.014s)
# video 1/1 (150/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.014s)
# video 1/1 (151/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.016s)
# video 1/1 (152/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (153/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.015s)
# video 1/1 (154/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.016s)
# video 1/1 (155/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.014s)
# video 1/1 (156/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.016s)
# video 1/1 (157/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.017s)
# video 1/1 (158/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.016s)
# video 1/1 (159/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.013s)
# video 1/1 (160/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.012s)
# video 1/1 (161/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.013s)
# video 1/1 (162/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 4
# Done. (0.014s)
# video 1/1 (163/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 4
# Done. (0.016s)
# video 1/1 (164/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 4
# Done. (0.025s)
# video 1/1 (165/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.017s)
# video 1/1 (166/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 4
# Done. (0.018s)
# video 1/1 (167/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
#
# [Detections]
# 1 birds,
# [Tracks] 4
# Done. (0.017s)
# video 1/1 (168/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (169/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (170/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (171/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (172/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (173/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (174/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (175/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (176/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (177/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (178/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (179/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (180/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (181/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.015s)
# video 1/1 (182/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (183/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (184/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (185/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (186/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (187/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (188/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.014s)
# video 1/1 (189/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (190/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.011s)
# video 1/1 (191/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (192/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (193/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (194/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (195/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (196/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (197/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (198/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (199/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (200/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (201/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (202/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (203/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.014s)
# video 1/1 (204/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (205/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (206/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (207/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (208/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.010s)
# video 1/1 (209/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (210/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (211/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (212/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (213/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.009s)
# video 1/1 (214/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.008s)
# video 1/1 (215/215) /content/zero-shot-object-tracking/data/video/fish.mp4: yolov5 inference
# Done. (0.008s)
# Results saved to runs/detect/exp2
# Done. (11.259s)

# %%
#Download and view the video on your host device
from google.colab import files
files.download("./runs/detect/exp/cars.mp4")
